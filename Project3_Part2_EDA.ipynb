# %%
import os, time,json
import tmdbsimple as tmdb 
import pandas as pd
from tqdm.notebook import tqdm_notebook

# %%
with open('/Users/siblose/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
tmdb.API_KEY =  login['api-key']
FOLDER = "Project3Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2019.json',
#  'tmdb_api_results_2020.json']

# %%
# Load in the dataframe results of each year
year2000df = pd.read_csv('Project3Data/final_tmdb_data_2000.csv.gz')

# %%
year2000df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
# Load in the dataframe results of each year
year2001df = pd.read_csv('Project3Data/final_tmdb_data_2001.csv.gz')
year2001df.tail()
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1358  tt7797790    0.0                               NaN
# 1359  tt8665056    0.0                               NaN
# 1360  tt8795764    0.0                               NaN
# 1361  tt9071078    0.0  /51274Q2vnmajonyiqq3YNQQ7q4I.jpg
# 1362  tt9212730    0.0                               NaN
#
#      belongs_to_collection    budget  \
# 1358                   NaN       0.0
# 1359                   NaN       0.0
# 1360                   NaN       0.0
# 1361                   NaN  127389.0
# 1362                   NaN       0.0
#
#                                                  genres  \
# 1358                     [{'id': 27, 'name': 'Horror'}]
# 1359                    [{'id': 37, 'name': 'Western'}]
# 1360                     [{'id': 27, 'name': 'Horror'}]
# 1361  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 1362  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
# ...

# %%
# concatenating df1 and df2 along rows
finaldf = pd.concat([year2000df, year2001df], axis=0)
finaldf.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
finaldf.tail()
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1358  tt7797790    0.0                               NaN
# 1359  tt8665056    0.0                               NaN
# 1360  tt8795764    0.0                               NaN
# 1361  tt9071078    0.0  /51274Q2vnmajonyiqq3YNQQ7q4I.jpg
# 1362  tt9212730    0.0                               NaN
#
#      belongs_to_collection    budget  \
# 1358                   NaN       0.0
# 1359                   NaN       0.0
# 1360                   NaN       0.0
# 1361                   NaN  127389.0
# 1362                   NaN       0.0
#
#                                                  genres  \
# 1358                     [{'id': 27, 'name': 'Horror'}]
# 1359                    [{'id': 37, 'name': 'Western'}]
# 1360                     [{'id': 27, 'name': 'Horror'}]
# 1361  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 1362  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2625 entries, 0 to 1362
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2625 non-null   object
#  1   adult                  2623 non-null   float64
#  2   backdrop_path          1471 non-null   object
#  3   belongs_to_collection  212 non-null    object
#  4   budget                 2623 non-null   float64
#  5   genres                 2623 non-null   object
#  6   homepage               172 non-null    object
#  7   id                     2623 non-null   float64
#  8   original_language      2623 non-null   object
#  9   original_title         2623 non-null   object
#  10  overview               2572 non-null   object
#  11  popularity             2623 non-null   float64
#  12  poster_path            2382 non-null   object
#  13  production_companies   2623 non-null   object
# ...

# %% [markdown]
#  light EDA

# %%
#How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
rslt_df = finaldf[(finaldf['budget'] > 0) | (finaldf['revenue'] > 0)  ]

# %%
rslt_df.shape
# Out:
# (650, 26)

# %%
#Answer :there are 650 movies

# %%
#How many movies are there in each of the certification categories (G/PG/PG-13/R)?
rslt_df['certification'].value_counts()
# Out:
# R        220
# PG-13    123
# PG        35
# G         16
# NR        14
# Name: certification, dtype: int64

# %%
#What is the average revenue per certification category?
grouped = rslt_df.groupby('certification')
grouped['revenue'].mean()
# Out:
# certification
# G        1.109574e+08
# NR       5.311700e+06
# PG       9.819739e+07
# PG-13    9.229870e+07
# R        3.175520e+07
# Name: revenue, dtype: float64

# %%
#What is the average budget per certification category?
grouped = rslt_df.groupby('certification')
grouped['budget'].mean()
# Out:
# certification
# G        3.575000e+07
# NR       2.259650e+06
# PG       4.051421e+07
# PG-13    4.240779e+07
# R        1.906047e+07
# Name: budget, dtype: float64

# %%
# save the final results to a compressed csv
finaldf.to_csv('tmdb_results_combined.csv.gz', compression='gzip',index=False)
