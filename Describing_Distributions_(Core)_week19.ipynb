# %% [markdown]
# In this assignment, you will be analyzing & visualizing several features in the Medical Dataset.
#
# - The features to analyze:
#   - VitD_levels
#   - Doc_visits
#   - TotalCharge

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
df = pd.read_csv('data (4).csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# First Analyse VitD_levels

# %% [markdown]
# ###For each feature listed:
# 1.Plot a histogram with a kde (kernel density estimate)
# - Add a line for the mean (red)
# - Add a line for the median (green)
# - Add a line for for +1 std from the mean (black)
# - Add a line for the - 1 std from the mean (black)
# - Highlight the range between +1 and =1 std (yellow)

# %%
col = 'VitD_levels'

# %%
feature = df[col]
mean = feature.mean()
median = feature.median()

std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='density', kde = True)
ax.axvline(mean,color = 'red', label=f'Mean = {mean:,.2f}',)#line for mean
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')#Line for median

ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}') #line for +1 std
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}') #line for -1 std

#Highlight the range between +1 and =1 std (yellow)
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\siblose\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\siblose\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 2. Answer the following questions:
#
# Is it Discrete or Continuous?
# - Answer Continuous
#
# Does it have a skew? If so, which direction (+/-)
# - Answer is No
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
# - Mesokurtic

# %%
kurtvit = stats.kurtosis(df[col], fisher = False)
kurtvit
# Out:
# 3.013147515833447

# %% [markdown]
# 2. Analyse Doc_visits

# %%
col = 'Doc_visits'

# %%
feature = df[col]
mean = feature.mean()
median = feature.median()

std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='density',kde = True)
ax.axvline(mean,color = 'red', label=f'Mean = {mean:,.2f}',)#line for mean
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')#Line for median

ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}') #line for +1 std
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}') #line for -1 std

#Highlight the range between +1 and =1 std (yellow)
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\siblose\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\siblose\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
kurtdoc = stats.kurtosis(df[col], fisher = False)
kurtdoc
# Out:
# 2.9919958083381206

# %% [markdown]
# 2. Answer the following questions:
#
# Is it Discrete or Continuous?
# - Answer descrete
#
# Does it have a skew? If so, which direction (+/-)
# - Answer positively skew but a little
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
# - Platykurtic (its<3)

# %% [markdown]
# 3. Analyse TotalCharge

# %%
col = 'TotalCharge'

# %%
feature = df[col]
mean = feature.mean()
median = feature.median()

std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='density', kde = True)
ax.axvline(mean,color = 'red', label=f'Mean = {mean:,.2f}',)#line for mean
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')#Line for median

ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}') #line for +1 std
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}') #line for -1 std

#Highlight the range between +1 and =1 std (yellow)
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow')
ax.set_title(f'{col}')
ax.legend();
# Out:
# C:\Users\siblose\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\siblose\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
kurtchrg = stats.kurtosis(df[col], fisher = False)
kurtchrg
# Out:
# 3.2650077463439384

# %% [markdown]
# 2. Answer the following questions:
#
# Is it Discrete or Continuous?
# - Answer Continuous
#
# Does it have a skew? If so, which direction (+/-)
# - Answer is yes, positively skew
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
# - Leptokurtic  (it's>3)

# %% [markdown]
# NB
# Is it Discrete or Continuous?
# Continuous is a non whole number - float, discrete is a whole number.
